# %% [markdown]
# <a href="https://colab.research.google.com/github/muminovbogibek-source/Eshmat-AI/blob/main/requirements_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
python-telegram-bot==20.7
google-generativeai
